# %% [markdown]
# <a href="https://colab.research.google.com/github/HinataTsuji/data-science-toolkit/blob/main/Tutorial04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataframe=pd.read_csv('/content/drive/MyDrive/dataset.zip')     #pandas reading csv

# %%
dataframe.head()
# Out:
#         Brand    Country  Year  Monthly_Production_Tonnes  Avg_Item_Price_USD  \
# 0       Shein  Indonesia  2017                     574.51               19.31
# 1  Forever 21    Vietnam  2024                     394.50                9.30
# 2      Uniqlo      India  2024                     310.23               25.46
# 3  Forever 21        USA  2017                     218.65               13.17
# 4        Zara  Indonesia  2016                    1005.84               15.40
#
#    Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                       16                11421.58
# 1                       20                 5571.01
# 2                       11                10969.00
# 3                       13                13093.00
# 4                       20                 9548.40
#
#    Water_Usage_Million_Litres  Landfill_Waste_Tonnes  Avg_Worker_Wage_USD  \
# 0                      282.11                 616.63               143.79
# ...

# %%
dataframe.tail()
# Out:
#       Brand Country  Year  Monthly_Production_Tonnes  Avg_Item_Price_USD  \
# 2995   Zara   India  2020                     549.36               17.77
# 2996  Shein     USA  2021                     670.54               18.05
# 2997   Zara   China  2023                     370.31               22.25
# 2998  Shein  Brazil  2015                     649.20               23.00
# 2999   Zara   India  2018                     602.77               13.95
#
#       Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 2995                       21                11214.01
# 2996                       24                10548.69
# 2997                       22                 3385.09
# 2998                       14                10822.80
# 2999                       28                 8013.18
#
#       Water_Usage_Million_Litres  Landfill_Waste_Tonnes  Avg_Worker_Wage_USD  \
# 2995                       87.08                 768.13               165.22
# ...

# %%
dataframe.columns
# Out:
# Index(['Brand', 'Country', 'Year', 'Monthly_Production_Tonnes',
#        'Avg_Item_Price_USD', 'Release_Cycles_Per_Year',
#        'Carbon_Emissions_tCO2e', 'Water_Usage_Million_Litres',
#        'Landfill_Waste_Tonnes', 'Avg_Worker_Wage_USD',
#        'Working_Hours_Per_Week', 'Child_Labor_Incidents',
#        'Return_Rate_Percent', 'Avg_Spend_Per_Customer_USD',
#        'Shopping_Frequency_Per_Year', 'Instagram_Mentions_Thousands',
#        'TikTok_Mentions_Thousands', 'Sentiment_Score',
#        'Social_Sentiment_Label', 'GDP_Contribution_Million_USD',
#        'Env_Cost_Index', 'Sustainability_Score', 'Transparency_Index',
#        'Compliance_Score', 'Ethical_Rating'],
#       dtype='object')

# %%
dataframe.to_numpy()
# Out:
# array([['Shein', 'Indonesia', 2017, ..., 61.19, 13.95, 1.46],
#        ['Forever 21', 'Vietnam', 2024, ..., 3.44, 90.93, 1.29],
#        ['Uniqlo', 'India', 2024, ..., 60.7, 27.6, 1.48],
#        ...,
#        ['Zara', 'China', 2023, ..., 75.29, 55.28, 0.2],
#        ['Shein', 'Brazil', 2015, ..., 16.66, 20.73, 2.89],
#        ['Zara', 'India', 2018, ..., 94.53, 40.91, 3.53]], dtype=object)

# %% [markdown]
# My question is: In the last 5 years, how much percentage of SHEIN products' has over 50% of Environmental Cost Index and negative social sentinent?
#
# *can state about relationship - environmental impact and how people are willing to change?*
#
# production line and waste contribute to negative social and environmental impact? (e.g. child labor, workforce exploitation, carbon emission, water usage, landfill waste over 1k tonnes)
#
# *please put each characteristic inside the question to make it specific*
#
# What can we conclude from this fast fashion trend for the next 5 years? What can we do to decrease the percentage of SHEIN products' production impact by 5%?
#
# 2. This dataset has enough samples with 25 columns and 3000 rows. 5 brands (SHEIN, H&M, Forever 21, Zara, Uniqlo), Large consumer market countries (Bangladesh, Brazil, China, Germany, India, Indonesia, Turkey, UK, USA, Vietnam). Wide timeline from year 2015 to 2024, and lots of characteristics for the columns to observe and analyze from.
#
# 3. There are 25 columns that represent 25 features. It is enough.
#
# 4. We have approximately 50 samples/observation for each brand and country, thus it is enough.
#
# 5. The dataset consists of quantitative(numerical, discrete for Child_Labor, continuous for most of it) and qualitative(categorical) datatypes. Most of them are quantitative, while the qualitative (ordinal) data examples are "social sentinent". It can be represented using Tabular, Graphical, or Time Series visualization.
#
# 6. None of the columns have null values.
#
# 7. Featured Columns: Monthly_Production_Tonnes, Release_Cycles_Per_Year, Carbon_Emmissions, Water_Usage, Landfill_Waste, Working_Hours, Child_Labor_Incidents, Return_Rate, Social_Sentinent (whether we want to sway the public on reducing fast fashion purchases), Env_Cost, Sustainability_Score
# Target output is the Carbon_Emmissions, Water_Usage, Landfill_Waste, Social_Sentinent, Env_Cost, Sustainability_Score, Ethical_Rating
#
# 8. No.
#
# 9. Going back to my question above. The type of question that can be asked is a relationship question. Or a comparison question between brands. Or a composition of environmental impact of fast fashion. Yes the dataset suits the question we are asking.
#
# Further opinions: The data can be tidied into SHEIN -> countries_year for easier observation

# %%
print(dataframe.isnull().sum())  # or use .any()
# Out:
# Brand                           0
# Country                         0
# Year                            0
# Monthly_Production_Tonnes       0
# Avg_Item_Price_USD              0
# Release_Cycles_Per_Year         0
# Carbon_Emissions_tCO2e          0
# Water_Usage_Million_Litres      0
# Landfill_Waste_Tonnes           0
# Avg_Worker_Wage_USD             0
# Working_Hours_Per_Week          0
# Child_Labor_Incidents           0
# Return_Rate_Percent             0
# Avg_Spend_Per_Customer_USD      0
# Shopping_Frequency_Per_Year     0
# Instagram_Mentions_Thousands    0
# TikTok_Mentions_Thousands       0
# Sentiment_Score                 0
# Social_Sentiment_Label          0
# GDP_Contribution_Million_USD    0
# Env_Cost_Index                  0
# Sustainability_Score            0
# Transparency_Index              0
# Compliance_Score                0
# Ethical_Rating                  0
# dtype: int64
